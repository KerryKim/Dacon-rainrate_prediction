# %%
import numpy as np
import matplotlib.pyplot as plt

color_map = plt.cm.get_cmap('RdBu')
color_map = color_map.reversed()

image_sample = np.load('data/train/subset_010464_05.npy')
plt.style.use('fivethirtyeight')

# %%
plt.figure(figsize=(30, 30))
for i in range(10):
    plt.subplot(1,11,i+1)
    plt.imshow(image_sample[:, :, i], cmap=color_map)

plt.subplot(1,11,11)
plt.imshow(image_sample[:,:,-1], cmap = color_map)
plt.show()

# %%
# 좌측 상단 붉은색 지역이 강수량으로 안나타남

# %%
image_sample = np.load('data/train/subset_010464_02.npy')
plt.figure(figsize=(30, 30))
for i in range(10):
    plt.subplot(1,11,i+1)
    plt.imshow(image_sample[:, :, i], cmap=color_map)

plt.subplot(1,11,11)
plt.imshow(image_sample[:,:,-1], cmap = color_map)
plt.show()

# %%
# 8번째, 9번째 라벨에 온도가 비정상으로 높게 보임

# %%
image_sample = np.load('data/train/subset_010462_01.npy')
plt.figure(figsize=(30, 30))
for i in range(10):
    plt.subplot(1,11,i+1)
    plt.imshow(image_sample[:, :, i], cmap=color_map)

plt.subplot(1,11,11)
plt.imshow(image_sample[:,:,-1], cmap = color_map)
plt.show()

# %%
# 1,2 번째 라벨에 선명하고 전체적으로 우측에 온도분포가 있는데 강수량은 거의없음

# %%
image_sample = np.load('data/train/subset_010462_04.npy')
plt.figure(figsize=(30, 30))
for i in range(10):
    plt.subplot(1,11,i+1)
    plt.imshow(image_sample[:, :, i], cmap=color_map)

plt.subplot(1,11,11)
plt.imshow(image_sample[:,:,-1], cmap = color_map)
plt.show()

# %%
#1,2번째 상단 온도분포가 강수량에 안나타남

# %%
image_sample = np.load('data/train/subset_010462_06.npy')
plt.figure(figsize=(30, 30))
for i in range(10):
    plt.subplot(1,11,i+1)
    plt.imshow(image_sample[:, :, i], cmap=color_map)

plt.subplot(1,11,11)
plt.imshow(image_sample[:,:,-1], cmap = color_map)
plt.show()

# %%
# 온도분포가 강하게 나타나는데 null data?

# %%
image_sample = np.load('data/train/subset_010462_07.npy')
plt.figure(figsize=(30, 30))
for i in range(10):
    plt.subplot(1,11,i+1)
    plt.imshow(image_sample[:, :, i], cmap=color_map)

plt.subplot(1,11,11)
plt.imshow(image_sample[:,:,-1], cmap = color_map)
plt.show()

# %%
# 위와 동일

# %%
image_sample = np.load('data/train/subset_010463_10.npy')
plt.figure(figsize=(30, 30))
for i in range(10):
    plt.subplot(1,11,i+1)
    plt.imshow(image_sample[:, :, i], cmap=color_map)

plt.subplot(1,11,11)
plt.imshow(image_sample[:,:,-1], cmap = color_map)
plt.show()

# %%
# 1,2번째 라벨이 전체적인 강수량을 잘 못잡음

# %%
image_sample = np.load('data/train/subset_010463_11.npy')
plt.figure(figsize=(30, 30))
for i in range(10):
    plt.subplot(1,11,i+1)
    plt.imshow(image_sample[:, :, i], cmap=color_map)

plt.subplot(1,11,11)
plt.imshow(image_sample[:,:,-1], cmap = color_map)
plt.show()

# %%
# 가운데 강한 온도 분포가 존재하는데 강수량은 전혀 안잡힘

# %%
image_sample = np.load('data/train/subset_010463_12.npy')
plt.figure(figsize=(30, 30))
for i in range(10):
    plt.subplot(1,11,i+1)
    plt.imshow(image_sample[:, :, i], cmap=color_map)

plt.subplot(1,11,11)
plt.imshow(image_sample[:,:,-1], cmap = color_map)
plt.show()

# %%
# 위와 동일

# %%
image_sample = np.load('data/train/subset_010464_02.npy')
plt.figure(figsize=(30, 30))
for i in range(10):
    plt.subplot(1,11,i+1)
    plt.imshow(image_sample[:, :, i], cmap=color_map)

plt.subplot(1,11,11)
plt.imshow(image_sample[:,:,-1], cmap = color_map)
plt.show()

# %%
# 8,9번째 라벨 온도분포가 평균적으로 높음.

# %%
image_sample = np.load('data/train/subset_010464_05.npy')
plt.figure(figsize=(30, 30))
for i in range(10):
    plt.subplot(1,11,i+1)
    plt.imshow(image_sample[:, :, i], cmap=color_map)

plt.subplot(1,11,11)
plt.imshow(image_sample[:,:,-1], cmap = color_map)
plt.show()

# %%
# 좌측상단 강한 온도분포 못잡음

# %%
image_sample = np.load('data/train/subset_017872_03.npy')
plt.figure(figsize=(30, 30))
for i in range(10):
    plt.subplot(1,11,i+1)
    plt.imshow(image_sample[:, :, i], cmap=color_map)

plt.subplot(1,11,11)
plt.imshow(image_sample[:,:,-1], cmap = color_map)
plt.show()

# %%
# 1,2번째 라벨이 이상하고 전체적으로 다 못잡음

# %%
image_sample = np.load('data/train/subset_017872_05.npy')
plt.figure(figsize=(30, 30))
for i in range(10):
    plt.subplot(1,11,i+1)
    plt.imshow(image_sample[:, :, i], cmap=color_map)

plt.subplot(1,11,11)
plt.imshow(image_sample[:,:,-1], cmap = color_map)
plt.show()

# %%
# 온도분포는 강한데 비해 강수량이 못잡는 부분있음

# %%
image_sample = np.load('data/train/subset_017873_02.npy')
plt.figure(figsize=(30, 30))
for i in range(10):
    plt.subplot(1,11,i+1)
    plt.imshow(image_sample[:, :, i], cmap=color_map)

plt.subplot(1,11,11)
plt.imshow(image_sample[:,:,-1], cmap = color_map)
plt.show()

# %%
# 이상한 null data

# %%
image_sample = np.load('data/train/subset_017873_03.npy')
plt.figure(figsize=(30, 30))
for i in range(10):
    plt.subplot(1,11,i+1)
    plt.imshow(image_sample[:, :, i], cmap=color_map)

plt.subplot(1,11,11)
plt.imshow(image_sample[:,:,-1], cmap = color_map)
plt.show()

# %%
# 이상한 null datea

# %%
image_sample = np.load('data/train/subset_017876_02.npy')
plt.figure(figsize=(30, 30))
for i in range(10):
    plt.subplot(1,11,i+1)
    plt.imshow(image_sample[:, :, i], cmap=color_map)

plt.subplot(1,11,11)
plt.imshow(image_sample[:,:,-1], cmap = color_map)
plt.show()

# %%
# 8,9번째 라벨에서만 특징이 나타남

# %%
image_sample = np.load('data/train/subset_017873_04.npy')
plt.figure(figsize=(30, 30))
for i in range(10):
    plt.subplot(1,11,i+1)
    plt.imshow(image_sample[:, :, i], cmap=color_map)

plt.subplot(1,11,11)
plt.imshow(image_sample[:,:,-1], cmap = color_map)
plt.show()

# %%
# 이상한 데이터

# %%
image_sample = np.load('data/train/subset_017873_05.npy')
plt.figure(figsize=(30, 30))
for i in range(10):
    plt.subplot(1,11,i+1)
    plt.imshow(image_sample[:, :, i], cmap=color_map)

plt.subplot(1,11,11)
plt.imshow(image_sample[:,:,-1], cmap = color_map)
plt.show()

# %%
# 온도데이터가 강수량의 특성을 못잡음

# %%
image_sample = np.load('data/train/subset_010624_03.npy')
plt.figure(figsize=(30, 30))
for i in range(10):
    plt.subplot(1,11,i+1)
    plt.imshow(image_sample[:, :, i], cmap=color_map)

plt.subplot(1,11,11)
plt.imshow(image_sample[:,:,-1], cmap = color_map)
plt.show()

# %%
# 이상한 널데이터
